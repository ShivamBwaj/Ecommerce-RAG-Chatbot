# %% [markdown]
# ### import dep

# %%
from langsmith import Client

# %% [markdown]
# ### attach feedback to a specific trace in langsmith

# %% [markdown]
# 01a000ad-4a9d-7182-a201-48ff853baf66

# %%
rid="01a000ad-4a9d-7182-a201-48ff853baf66"

# %%
client=Client()

# %%
id
# Out:
# <function id(obj, /)>

# %%
client.create_feedback(
    run_id=rid,
    key="feedback",
    score=0,
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('01a001c5-54c1-7713-a4cf-4fc6844fc84a'), created_at=datetime.datetime(2026, 8, 14, 19, 35, 4, 641680, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 8, 14, 19, 35, 4, 641680, tzinfo=datetime.timezone.utc), run_id=UUID('01a000ad-4a9d-7182-a201-48ff853baf66'), trace_id=None, key='feedback', score=0, value=None, comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, start_time=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id=rid,
    key="comments",
    value="This is a test feedback comment.",
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('01a001c9-4f27-7f81-87c6-dc4d228a2e2a'), created_at=datetime.datetime(2026, 8, 14, 19, 39, 25, 351866, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 8, 14, 19, 39, 25, 351866, tzinfo=datetime.timezone.utc), run_id=UUID('01a000ad-4a9d-7182-a201-48ff853baf66'), trace_id=None, key='comments', score=None, value='This is a test feedback comment.', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, start_time=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)

# %%
client.create_feedback(
    run_id=rid,
    key="comments_with_score",
    value="This is a test feedback comment.",
    score=0,
    feedback_source_type="api"
)
# Out:
# Feedback(id=UUID('01a001ca-5db9-7653-b30d-10a72fa7109c'), created_at=datetime.datetime(2026, 8, 14, 19, 40, 34, 617375, tzinfo=datetime.timezone.utc), modified_at=datetime.datetime(2026, 8, 14, 19, 40, 34, 617375, tzinfo=datetime.timezone.utc), run_id=UUID('01a000ad-4a9d-7182-a201-48ff853baf66'), trace_id=None, key='comments_with_score', score=0, value='This is a test feedback comment.', comment=None, correction=None, feedback_source=FeedbackSourceBase(type='api', metadata={}, user_id=None, user_name=None), session_id=None, start_time=None, comparative_experiment_id=None, feedback_group_id=None, extra=None)
